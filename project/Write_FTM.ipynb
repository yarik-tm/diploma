# %%
import pandas as pd

from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, insert, text

# %%
Base = automap_base()

engine = create_engine('postgresql://postgres:rootroot@[::1]:5432/userdb')


Base.prepare(engine, reflect=True)
# Out:
# C:\Users\yarik\AppData\Local\Temp\ipykernel_13360\3914178768.py:6: SADeprecationWarning: The AutomapBase.prepare.reflect parameter is deprecated and will be removed in a future release.  Reflection is enabled when AutomapBase.prepare.autoload_with is passed.
#   Base.prepare(engine, reflect=True)

# %%
conn = engine.connect()

# %%
import datetime

# %%
year = datetime.date.today().year
cntry = 'Mexico'
frdm = 1
govt_trust = 1
generosity = 1
howhapp = 10

# no column specification needed if all columns are inserted
# stmt = f"INSERT INTO feed_the_machine VALUES ('{cntry}', {frdm}, {govt_trust}, {generosity}, {year}, {howhapp});"

# print(stmt)

# conn.execute(stmt)
